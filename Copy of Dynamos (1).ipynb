# %%
#import important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading and uploading data
df=pd.read_csv("/content/Copy of Netflix_data.csv")

# %%
#(3) checking top 5 rows of the data using .head() function
df.head()
# Out:
#                                            Title        Date
# 0                               Almost Christmas  24/12/2024
# 1                              Our Little Secret  18/12/2024
# 2                 Twas the Text Before Christmas  18/12/2024
# 3  My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4      My Demon: Limited Series: The End of Fate  10/12/2024

# %%
#(4) Number of rows and columns in the dataset
df.shape
# Out:
# (115, 2)

# %%
#(5) Number of rows in the dataset
df.shape[0]
# Out:
# 115

# %%
#(6) Number of columns in the dataset
df.shape[1]
# Out:
# 2

# %%
#(7) Description of the dataset
df.describe()
# Out:
#                    Title        Date
# count                115         115
# unique               115          48
# top     Almost Christmas  21/07/2024
# freq                   1          13

# %%
#(8)information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   115 non-null    object
#  1   Date    115 non-null    object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
#checking for empty spaces
df.isnull().sum()
# Out:
# Title    0
# Date     0
# dtype: int64

# %%
df.isnull()
# Out:
#      Title   Date
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 110  False  False
# 111  False  False
# 112  False  False
# 113  False  False
# 114  False  False
#
# [115 rows x 2 columns]

# %%
df.isna()
# Out:
#      Title   Date
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 110  False  False
# 111  False  False
# 112  False  False
# 113  False  False
# 114  False  False
#
# [115 rows x 2 columns]

# %%
df.iloc()

# %%
df.loc

# %%
df["Title"].apply(lambda title: "The Union" in title) .sum()
# Out:
# 1

# %%
df[df["Title"].apply(lambda title: "Almost Christmas" in title)]
# Out:
#               Title        Date
# 0  Almost Christmas  24/12/2024
